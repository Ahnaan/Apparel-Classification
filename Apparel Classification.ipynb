# %% [markdown]
# # Apparel Classification Project

# %% [markdown]
# ### Reading the image folders

# %%
folder1 = 'black_dress'
folder2 = 'black_pants'
folder3 = 'black_shirt'
folder4 = 'black_shoes'
folder5 = 'black_shorts'
folder6 = 'blue_dress'
folder7 = 'blue_pants'
folder8 = 'blue_shirt'
folder9 = 'blue_shoes'
folder10 = 'blue_shorts'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading every image in an empty list

# %%
import os
import cv2
black_dress = []
for filename in os.listdir(folder1):
  imgg = plt.imread(os.path.join(folder1,filename))
  resized_img = cv2.resize(imgg , (350,350))
  black_dress.append(resized_img)

# %%
black_pants = []
for filename in os.listdir(folder2):
  imgg = plt.imread(os.path.join(folder2,filename))
  resized_img = cv2.resize(imgg , (350,350))
  black_pants.append(resized_img)

# %%
black_shirt = []
for filename in os.listdir(folder3):
  imgg = plt.imread(os.path.join(folder3,filename))
  resized_img = cv2.resize(imgg , (350,350))
  black_shirt.append(resized_img)

# %%
black_shoes = []
for filename in os.listdir(folder4):
  imgg = plt.imread(os.path.join(folder4,filename))
  resized_img = cv2.resize(imgg , (350,350))
  black_shoes.append(resized_img)

# %%
black_shorts = []
for filename in os.listdir(folder5):
  imgg = plt.imread(os.path.join(folder5,filename))
  resized_img = cv2.resize(imgg , (350,350))
  black_shorts.append(resized_img)

# %%
blue_dress = []
for filename in os.listdir(folder6):
  imgg = plt.imread(os.path.join(folder6,filename))
  resized_img = cv2.resize(imgg , (350,350))
  blue_dress.append(resized_img)

# %%
blue_pants = []
for filename in os.listdir(folder7):
  imgg = plt.imread(os.path.join(folder7,filename))
  resized_img = cv2.resize(imgg , (350,350))
  blue_pants.append(resized_img)

# %%
blue_shirt = []
for filename in os.listdir(folder8):
  imgg = plt.imread(os.path.join(folder8,filename))
  resized_img = cv2.resize(imgg , (350,350))
  blue_shirt.append(resized_img)

# %%
blue_shoes = []
for filename in os.listdir(folder9):
  imgg = plt.imread(os.path.join(folder9,filename))
  resized_img = cv2.resize(imgg , (350,350))
  blue_shoes.append(resized_img)

# %%
blue_shorts = []
for filename in os.listdir(folder10):
  imgg = plt.imread(os.path.join(folder10,filename))
  resized_img = cv2.resize(imgg , (350,350))
  blue_shorts.append(resized_img)

# %% [markdown]
# ### Converting to numpy arrays

# %%
black_dress = np.array(black_dress)
np.shape(black_dress)
# Out:
# (450, 350, 350, 3)

# %%
black_pants = np.array(black_pants)
np.shape(black_pants)
# Out:
# (871, 350, 350, 3)

# %%
black_shirt = np.array(black_shirt)
np.shape(black_shirt)
# Out:
# (715, 350, 350, 3)

# %%
black_shoes = np.array(black_shoes)
np.shape(black_shoes)
# Out:
# (766, 350, 350, 3)

# %%
black_shorts = np.array(black_shorts)
np.shape(black_shorts)
# Out:
# (328, 350, 350, 3)

# %%
blue_dress = np.array(blue_dress)
np.shape(blue_dress)
# Out:
# (502, 350, 350, 3)

# %%
blue_pants = np.array(blue_pants)
np.shape(blue_pants)
# Out:
# (798, 350, 350, 3)

# %%
blue_shirt = np.array(blue_shirt)
np.shape(blue_shirt)
# Out:
# (741, 350, 350, 3)

# %%
blue_shoes = np.array(blue_shoes)
np.shape(blue_shoes)
# Out:
# (523, 350, 350, 3)

# %%
blue_shorts = np.array(blue_shorts)
np.shape(blue_shorts)
# Out:
# (299, 350, 350, 3)

# %% [markdown]
# ### Sample Images

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(black_dress[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(black_dress[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(black_dress[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(black_dress[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(black_dress[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(black_pants[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(black_pants[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(black_pants[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(black_pants[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(black_pants[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(black_shirt[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(black_shirt[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(black_shirt[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(black_shirt[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(black_shirt[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(black_shoes[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(black_shoes[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(black_shoes[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(black_shoes[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(black_shoes[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(black_shorts[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(black_shorts[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(black_shorts[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(black_shorts[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(black_shorts[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(blue_dress[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(blue_dress[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(blue_dress[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(blue_dress[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(blue_dress[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(blue_pants[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(blue_pants[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(blue_pants[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(blue_pants[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(blue_pants[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(blue_shirt[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(blue_shirt[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(blue_shirt[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(blue_shirt[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(blue_shirt[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(blue_shoes[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(blue_shoes[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(blue_shoes[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(blue_shoes[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(blue_shoes[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %%
rows = 2
columns = 3
fig = plt.figure(figsize=(10, 7))

fig.add_subplot(rows, columns, 1)
plt.imshow(blue_shorts[0])
plt.axis('off')

fig.add_subplot(rows, columns, 2)
plt.imshow(blue_shorts[1])
plt.axis('off')

fig.add_subplot(rows, columns, 3)
plt.imshow(blue_shorts[2])
plt.axis('off')

fig.add_subplot(rows, columns, 4)
plt.imshow(blue_shorts[3])
plt.axis('off')

fig.add_subplot(rows, columns, 5)
plt.imshow(blue_shorts[4])
plt.axis('off')
# Out:
# (-0.5, 349.5, 349.5, -0.5)

# %% [markdown]
# ### Creating our X and y variables

# %%
x = np.concatenate([black_dress, black_pants, black_shirt, black_shoes, black_shorts, blue_dress, blue_pants, blue_shirt, blue_shoes, blue_shorts])

# %%
x.shape
# Out:
# (5993, 350, 350, 3)

# %%
y1 = np.zeros(450)
y2 = np.ones(871)
y3 = np.full(shape=(715), fill_value = 2)
y4 = np.full(shape=(766), fill_value = 3)
y5 = np.full(shape=(328), fill_value = 4)
y6 = np.full(shape=(502), fill_value = 5)
y7 = np.full(shape=(798), fill_value = 6)
y8 = np.full(shape=(741), fill_value = 7)
y9 = np.full(shape=(523), fill_value = 8)
y10 = np.full(shape=(299), fill_value = 9)
y = np.concatenate([y1 , y2, y3, y4, y5, y6, y7, y8, y9, y10])
y = y.reshape(-1 , 1)

# %%
y.shape
# Out:
# (5993, 1)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y)

# %%
y.shape
# Out:
# (5993, 10)

# %% [markdown]
# ### Model Building

# %%
from keras.layers import Dense, Flatten , Conv2D , MaxPooling2D
from keras.models import Sequential

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), activation='relu', padding='same',input_shape=(350 , 350 , 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 350, 350, 64)      1792
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 350, 350, 32)      18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 175, 175, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 175, 175, 64)      18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 175, 175, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 87, 87, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 484416)            0
# ...

# %%
model.compile(optimizer = 'Adam' , loss = 'CategoricalCrossentropy' , metrics = ['accuracy'])

# %%
model.fit(x , y , epochs = 5)
# Out:
# Epoch 1/5
# 188/188 [==============================] - 2616s 14s/step - loss: 1.3068 - accuracy: 0.5633
# Epoch 2/5
# 188/188 [==============================] - 2773s 15s/step - loss: 0.4834 - accuracy: 0.8447
# Epoch 3/5
# 188/188 [==============================] - 2651s 14s/step - loss: 0.1843 - accuracy: 0.9488
# Epoch 4/5
# 188/188 [==============================] - 2488s 13s/step - loss: 0.0992 - accuracy: 0.9781
# Epoch 5/5
# 188/188 [==============================] - 2164s 12s/step - loss: 0.0713 - accuracy: 0.9808

# %%
model.evaluate(x, y)
# Out:
# 188/188 [==============================] - 362s 2s/step - loss: 0.0311 - accuracy: 0.9918
# [0.03108355402946472, 0.9918237924575806]

# %% [markdown]
# ### Testing on known images

# %%
x[0].shape
# Out:
# (350, 350, 3)

# %%
test = x[1800] 
test = test.reshape(1, 350, 350, 3)

# %%
np.argmax(model.predict(test), axis=-1)
# Out:
# array([2], dtype=int64)

# %%
test1 = x[0] 
test1 = test1.reshape(1, 350, 350, 3)

# %%
np.argmax(model.predict(test1), axis=-1)
# Out:
# array([0], dtype=int64)

# %%
model.save("bdproject.h5")

# %%
testimgg = plt.imread(os.path.join('testimage.jpg'))
resized_img = cv2.resize(testimgg , (350,350))

# %%
testimage = np.array(resized_img)

# %%
testimage.shape
# Out:
# (350, 350, 3)

# %%
testimage = testimage.reshape(1,350,350, 3)

# %%
np.argmax(model.predict(testimage), axis=-1)
# Out:
# array([0], dtype=int64)

# %% [markdown]
# ### Testing on test images

# %%
testimg = plt.imread(os.path.join('testimage2.jpg'))
resized_img2 = cv2.resize(testimg , (350,350))

# %%
testimage2 = np.array(resized_img2)

# %%
testimage2.shape
# Out:
# (350, 350, 3)

# %%
testimage2 = testimage2.reshape(1,350,350, 3)

# %%
np.argmax(model.predict(testimage2), axis=-1)
# Out:
# array([7], dtype=int64)

# %%
plt.imshow(resized_img)

# %%
plt.imshow(resized_img2)
